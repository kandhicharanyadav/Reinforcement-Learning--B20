# %% [markdown]
# <a href="https://colab.research.google.com/github/kandhicharanyadav/Reinforcement-Learning--B20/blob/main/Assignment_Lab_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Lab assignment - 4 :**

# %% [markdown]
# **Question - 1 :**

# %%
import math

machines = ['A', 'B', 'C']

rewards = {
    'A': [3, 4, 2, 5],
    'B': [6, 7, 5, 8],
    'C': [4, 3, 5, 4]
}

N = {'A': 0, 'B': 0, 'C': 0}
R = {'A': 0, 'B': 0, 'C': 0}
Q = {'A': 0, 'B': 0, 'C': 0}
UCB = {'A': 0, 'B': 0, 'C': 0}

N_play = 10

for play in range(1, N_play + 1):

    if play <= 3:
        machine = machines[play - 1]

    else:
        for m in machines:
            UCB[m] = Q[m] + math.sqrt(
                (2 * math.log(play)) / N[m]
            )

        machine = max(machines, key=UCB.get)

    # Repeat reward pattern when necessary
    reward = rewards[machine][N[machine] % len(rewards[machine])]

    print("\nPlay:", play)
    print("Selected Machine:", machine)
    print("Reward:", reward)

    N[machine] += 1
    R[machine] += reward

    Q[machine] = Q[machine] + (
        (reward - Q[machine]) / N[machine]
    )

    print("Q-value:", Q[machine])

print("\nFinal Results")
print("Machine\tN\tR\tQ\tUCB")

for m in machines:
    UCB[m] = Q[m] + math.sqrt(
        (2 * math.log(N_play)) / N[m]
    )

    print(
        m, "\t",
        N[m], "\t",
        R[m], "\t",
        round(Q[m], 2), "\t",
        round(UCB[m], 2)
    )

print("\nTotal Reward =", sum(R.values()))
# Out:
# Play: 1
# Selected Machine: A
# Reward: 3
# Q-value: 3.0
#
# Play: 2
# Selected Machine: B
# Reward: 6
# Q-value: 6.0
#
# Play: 3
# Selected Machine: C
# Reward: 4
# Q-value: 4.0
#
# Play: 4
# Selected Machine: B
# Reward: 7
# Q-value: 6.5
#
# Play: 5
# Selected Machine: B
# Reward: 5
# Q-value: 6.0
#
# Play: 6
# Selected Machine: B
# Reward: 8
# Q-value: 6.5
#
# Play: 7
# Selected Machine: B
# Reward: 6
# Q-value: 6.4
#
# Play: 8
# Selected Machine: B
# Reward: 7
# Q-value: 6.5
#
# Play: 9
# Selected Machine: B
# Reward: 5
# Q-value: 6.285714285714286
#
# Play: 10
# Selected Machine: B
# Reward: 8
# Q-value: 6.5
#
# Final Results
# Machine	N	R	Q	UCB
# A 	 1 	 3 	 3.0 	 5.15
# B 	 8 	 52 	 6.5 	 7.26
# C 	 1 	 4 	 4.0 	 6.15
#
# Total Reward = 59
