# %% [markdown]
# <a href="https://colab.research.google.com/github/kandhicharanyadav/Reinforcement-Learning--B20/blob/main/Assignment_Lab_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Question - 1:**

# %%
import random

# Part A - Machine Initialization
machines = ['A', 'B', 'C']
N_play = 10
epsilon = 0.2
N = {'A': 0, 'B': 0, 'C': 0}
R = {'A': [], 'B': [], 'C': []}
Q = {'A': 0.0, 'B': 0.0, 'C': 0.0}
total_reward = 0
print("Modified Epsilon-Greedy Multi-Armed Bandit")
print("------------------------------------------")
for play in range(1, N_play + 1):
    r = random.random()
    best_machine = max(Q, key=Q.get)
    if r < epsilon:
        other_machines = [m for m in machines if m != best_machine]
        selected_machine = random.choice(other_machines)
        print(f"\nPlay {play}: Exploration")
    else:
        selected_machine = best_machine
        print(f"\nPlay {play}: Exploitation")
    print("Selected Machine:", selected_machine)
    reward = float(input(f"Enter reward for machine {selected_machine}: "))
    N[selected_machine] += 1
    R[selected_machine].append(reward)
    Q[selected_machine] = Q[selected_machine] + (
        (reward - Q[selected_machine]) / N[selected_machine]
    )
    total_reward += reward
    print("Updated Q-values:", Q)
# Part F - Display Results
print("\n========== FINAL RESULTS ==========")
print("\nN Table - Participation Count")
for machine in machines:
    print(machine, ":", N[machine])
print("\nR Table - Rewards")
for machine in machines:
    print(machine, ":", R[machine])
print("\nQ Table - Estimated Values")
for machine in machines:
    print(machine, ":", round(Q[machine], 2))
print("\nTotal Reward Received:", total_reward)
# Out:
# Modified Epsilon-Greedy Multi-Armed Bandit
# ------------------------------------------
#
# Play 1: Exploitation
# Selected Machine: A
# Enter reward for machine A: 10
# Updated Q-values: {'A': 10.0, 'B': 0.0, 'C': 0.0}
#
# Play 2: Exploration
# Selected Machine: C
# Enter reward for machine C: 5
# Updated Q-values: {'A': 10.0, 'B': 0.0, 'C': 5.0}
#
# Play 3: Exploitation
# Selected Machine: A
# Enter reward for machine A: 8
# Updated Q-values: {'A': 9.0, 'B': 0.0, 'C': 5.0}
#
# Play 4: Exploitation
# Selected Machine: A
# Enter reward for machine A: 9
# Updated Q-values: {'A': 9.0, 'B': 0.0, 'C': 5.0}
#
# Play 5: Exploitation
# Selected Machine: A
# Enter reward for machine A: 10
# Updated Q-values: {'A': 9.25, 'B': 0.0, 'C': 5.0}
#
# Play 6: Exploration
# Selected Machine: C
# Enter reward for machine C: 12
# Updated Q-values: {'A': 9.25, 'B': 0.0, 'C': 8.5}
#
# Play 7: Exploitation
# Selected Machine: A
# Enter reward for machine A: 9
# ...
