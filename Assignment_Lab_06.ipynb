# %% [markdown]
# <a href="https://colab.research.google.com/github/kandhicharanyadav/Reinforcement-Learning--B20/blob/main/Assignment_Lab_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Lab_Assignment - 6:**

# %%
# !pip install gymnasium

# %%
import gymnasium as gym
import numpy as np

# %%
def random_agent(env_name, episodes=5):

    print("=" * 60)
    print("Environment:", env_name)
    print("=" * 60)

    # Create environment
    env = gym.make(env_name)

    episode_rewards = []

    # Run multiple episodes
    for episode in range(1, episodes + 1):

        # Reset environment
        state, info = env.reset()

        total_reward = 0
        steps = 0

        terminated = False
        truncated = False

        # Continue until episode terminates
        while not (terminated or truncated):

            # Select a random action
            action = env.action_space.sample()

            # Execute action
            next_state, reward, terminated, truncated, info = env.step(action)

            # Update reward and steps
            total_reward += reward
            steps += 1

            # Move to next state
            state = next_state

        # Calculate average reward
        average_reward = total_reward / steps

        episode_rewards.append(total_reward)

        print(f"Episode {episode}")
        print(f"Steps          : {steps}")
        print(f"Total Reward   : {total_reward}")
        print(f"Average Reward : {average_reward:.2f}")
        print("-" * 40)

    # Display overall result
    print("\nTotal reward for each episode:")
    print(episode_rewards)

    print("Average Total Reward:",
          np.mean(episode_rewards))

    env.close()

# %%
random_agent("CliffWalking-v1", episodes=5)
# Out:
# ...
# Environment: CliffWalking-v1
# ...
# Episode 1
# Steps          : 1036
# Total Reward   : -10738
# Average Reward : -10.36
# ----------------------------------------
# Episode 2
# Steps          : 235
# Total Reward   : -2908
# Average Reward : -12.37
# ----------------------------------------
# Episode 3
# Steps          : 12943
# Total Reward   : -129070
# Average Reward : -9.97
# ----------------------------------------
# Episode 4
# Steps          : 6185
# Total Reward   : -60635
# Average Reward : -9.80
# ----------------------------------------
# Episode 5
# Steps          : 13445
# Total Reward   : -134423
# Average Reward : -10.00
# ----------------------------------------
#
# Total reward for each episode:
# [-10738, -2908, -129070, -60635, -134423]
# Average Total Reward: -67554.8

# %%
random_agent("Taxi-v4", episodes=5)
# Out:
# ...
# Environment: Taxi-v4
# ...
# Episode 1
# Steps          : 200
# Total Reward   : -857
# Average Reward : -4.29
# ----------------------------------------
# Episode 2
# Steps          : 200
# Total Reward   : -722
# Average Reward : -3.61
# ----------------------------------------
# Episode 3
# Steps          : 200
# Total Reward   : -884
# Average Reward : -4.42
# ----------------------------------------
# Episode 4
# Steps          : 200
# Total Reward   : -821
# Average Reward : -4.11
# ----------------------------------------
# Episode 5
# Steps          : 200
# Total Reward   : -758
# Average Reward : -3.79
# ----------------------------------------
#
# Total reward for each episode:
# [-857, -722, -884, -821, -758]
# Average Total Reward: -808.4
