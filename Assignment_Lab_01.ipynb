# %% [markdown]
# <a href="https://colab.research.google.com/github/kandhicharanyadav/Reinforcement-Learning--B20/blob/main/Assignment_Lab_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Question -1 :**

# %%
# 3 Code 1 — Greedy Algorithm using Arithmetic Mean
# Greedy Algorithm using Arithmetic Mean


n = int(input("Enter number of machines: "))
machines = {}


for i in range(n):
    name = input("Enter machine name: ")
    rewards = list(map(int, input("Enter rewards separated by space: ").split()))
    machines[name] = rewards


q_values = {}


for name in machines:
    rewards = machines[name]
    q = sum(rewards) / len(rewards)
    q_values[name] = q


    print("\nMachine", name)
    print("Rewards:", rewards)
    print("Q(" + name + ") =", round(q, 2))


# Find machine with highest Q value
selected = max(q_values, key=q_values.get)


print("\nGreedy Selected Machine:", selected)
# Out:
# Enter number of machines: 3
# Enter machine name: A
# Enter rewards separated by space: 3 2 4
# Enter machine name: B
# Enter rewards separated by space: 6 7
# Enter machine name: C
# Enter rewards separated by space: 5 4 6
#
# Machine A
# Rewards: [3, 2, 4]
# Q(A) = 3.0
#
# Machine B
# Rewards: [6, 7]
# Q(B) = 6.5
#
# Machine C
# Rewards: [5, 4, 6]
# Q(C) = 5.0
#
# Greedy Selected Machine: B

# %% [markdown]
# **Question - 2 :**

# %%
# Code 2 — Greedy Algorithm using Incremental Update
# Greedy Algorithm using Incremental Update


machines = {
    "A": [3, 2, 4],
    "B": [6, 7],
    "C": [5, 4, 6]
}


Q = {"A": 0, "B": 0, "C": 0}
N = {"A": 0, "B": 0, "C": 0}


for machine in machines:
    print("\nMachine", machine)


    for reward in machines[machine]:
        N[machine] += 1


        # Incremental update
        Q[machine] = Q[machine] + (reward - Q[machine]) / N[machine]


        print("Reward:", reward)
        print("N =", N[machine], "Q =", round(Q[machine], 2))


# Find the machine with highest Q value
selected = max(Q, key=Q.get)


print("\nFinal Q Values:")


for machine in Q:
    print("Q(" + machine + ") =", round(Q[machine], 2))


print("\nGreedy Selected Machine:", selected)
# Out:
# Machine A
# Reward: 3
# N = 1 Q = 3.0
# Reward: 2
# N = 2 Q = 2.5
# Reward: 4
# N = 3 Q = 3.0
#
# Machine B
# Reward: 6
# N = 1 Q = 6.0
# Reward: 7
# N = 2 Q = 6.5
#
# Machine C
# Reward: 5
# N = 1 Q = 5.0
# Reward: 4
# N = 2 Q = 4.5
# Reward: 6
# N = 3 Q = 5.0
#
# Final Q Values:
# Q(A) = 3.0
# Q(B) = 6.5
# Q(C) = 5.0
#
# Greedy Selected Machine: B
